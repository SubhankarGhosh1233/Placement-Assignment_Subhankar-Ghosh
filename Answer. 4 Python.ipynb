# %%
import pandas as pd
url = "https://data.nasa.gov/resource/y77d-th95.json"
df = pd.read_json(url)
df.head()
# Out:
#        name   id nametype     recclass      mass  fall  \
# 0    Aachen    1    Valid           L5      21.0  Fell
# 1    Aarhus    2    Valid           H6     720.0  Fell
# 2      Abee    6    Valid          EH4  107000.0  Fell
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4   Achiras  370    Valid           L6     780.0  Fell
#
#                       year    reclat    reclong  \
# 0  1880-01-01T00:00:00.000  50.77500    6.08333
# 1  1951-01-01T00:00:00.000  56.18333   10.23333
# 2  1952-01-01T00:00:00.000  54.21667 -113.00000
# 3  1976-01-01T00:00:00.000  16.88333  -99.90000
# 4  1902-01-01T00:00:00.000 -33.16667  -64.95000
#
#                                          geolocation  \
# 0  {'type': 'Point', 'coordinates': [6.08333, 50....
# 1  {'type': 'Point', 'coordinates': [10.23333, 56...
# 2  {'type': 'Point', 'coordinates': [-113, 54.216...
# 3  {'type': 'Point', 'coordinates': [-99.9, 16.88...
# 4  {'type': 'Point', 'coordinates': [-64.95, -33....
#
# ...

# %%
df.to_csv("file.csv")

# %%
data= pd.read_csv("file.csv")
data
# Out:
#      Unnamed: 0       name     id nametype               recclass      mass  \
# 0             0     Aachen      1    Valid                     L5      21.0
# 1             1     Aarhus      2    Valid                     H6     720.0
# 2             2       Abee      6    Valid                    EH4  107000.0
# 3             3   Acapulco     10    Valid            Acapulcoite    1914.0
# 4             4    Achiras    370    Valid                     L6     780.0
# ..          ...        ...    ...      ...                    ...       ...
# 995         995   Tirupati  24009    Valid                     H6     230.0
# 996         996    Tissint  54823    Valid  Martian (shergottite)    7000.0
# 997         997      Tjabe  24011    Valid                     H6   20000.0
# 998         998   Tjerebon  24012    Valid                     L5   16500.0
# 999         999  Tomakovka  24019    Valid                    LL6     600.0
#
# ...

# %%
df.columns
# Out:
# Index(['name', 'id', 'nametype', 'recclass', 'mass', 'fall', 'year', 'reclat',
#        'reclong', 'geolocation', ':@computed_region_cbhk_fwbd',
#        ':@computed_region_nnqa_25f4'],
#       dtype='object')
